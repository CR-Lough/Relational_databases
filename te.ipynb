# %%
import pandas as pd
load_dict = (pd.read_csv('accounts.csv')).to_dict(orient='records')

# %%
load_dict
# Out:
# [{'USER_ID': 'Brittaney.Gentry86',
#   'NAME': 'Brittaney',
#   'LASTNAME': 'Gentry',
#   'EMAIL': 'Brittaney.Gentry86@goodmail.com'},
#  {'USER_ID': 'Keri.Royce8',
#   'NAME': 'Keri',
#   'LASTNAME': 'Royce',
#   'EMAIL': 'Keri.Royce8@funmail.com'},
#  {'USER_ID': 'Michal.Hollyanne32',
#   'NAME': 'Michal',
#   'LASTNAME': 'Hollyanne',
#   'EMAIL': 'Michal.Hollyanne32@funmail.com'},
#  {'USER_ID': 'Carolina.Mateusz51',
#   'NAME': 'Carolina',
#   'LASTNAME': 'Mateusz',
#   'EMAIL': 'Carolina.Mateusz51@goodmail.com'},
#  {'USER_ID': 'Noni.Thetis66',
#   'NAME': 'Noni',
#   'LASTNAME': 'Thetis',
#   'EMAIL': 'Noni.Thetis66@goodmail.com'},
#  {'USER_ID': 'Grata.Ozzy95',
#   'NAME': 'Grata',
#   'LASTNAME': 'Ozzy',
#   'EMAIL': 'Grata.Ozzy95@testmail.com'},
#  {'USER_ID': 'Celisse.Schellens98',
#   'NAME': 'Celisse',
#   'LASTNAME': 'Schellens',
#   'EMAIL': 'Celisse.Schellens98@funmail.com'},
#  {'USER_ID': 'Harli.Dupaix47',
#   'NAME': 'Harli',
#   'LASTNAME': 'Dupaix',
# ...
